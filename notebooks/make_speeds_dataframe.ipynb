# %%
import pandas as pd
import plotly.express as px

# %%
df_trains = pd.read_excel("Inter station database.xls", sheet_name="Runtime", skiprows=1)
df_trains = df_trains.melt(
    id_vars=df_trains.columns[0:5],
    value_vars=df_trains.columns[5:8],
    var_name="Period",
    value_name="Time"
)
df_trains["Speed [m/min]"] = 1000 * df_trains["Distance (Kms)"] / df_trains["Time"]
df_trains["line_id"] = df_trains["Line"].map({
    "Bakerloo ":"bakerloo",
    "Central ":"central",
    "Circle ":"circle",
    "District":"district",
    "East London ":"london-overground",
    "H & C":"hammersmith-city",
    "Jubilee ":"jubilee",
    "Metropolitan":"metropolitan",
    "Northern ":"northern",
    "Piccadilly ":"piccadilly",
    "Victoria":"victoria",
    "Waterloo & City":"waterloo-city"
})
df_trains["mode"] = "tube"
df_trains.loc[df_trains["line_id"]=="london-overground","mode"] = "overground"
for period in df_trains["Period"].unique():
    df_trains = df_trains.append({
        "line_id":"dlr",
        "Speed [m/min]":64*1000/60,
        "mode":"dlr",
        "Period":period
    }, ignore_index=True)
df_trains.head()
# Out:
#         Line   Direction     Station from (A)    Station to (B)  \
# 0  Bakerloo   Southbound  HARROW & WEALDSTONE            KENTON
# 1  Bakerloo   Southbound               KENTON      SOUTH KENTON
# 2  Bakerloo   Southbound         SOUTH KENTON     NORTH WEMBLEY
# 3  Bakerloo   Southbound        NORTH WEMBLEY   WEMBLEY CENTRAL
# 4  Bakerloo   Southbound      WEMBLEY CENTRAL  STONEBRIDGE PARK
#
#    Distance (Kms)                          Period      Time  Speed [m/min]  \
# 0            1.74  Un-impeded Running Time (Mins)  2.233333     779.104478
# 1            1.40  Un-impeded Running Time (Mins)  1.883333     743.362832
# 2            0.90  Un-impeded Running Time (Mins)  1.500000     600.000000
# 3            1.27  Un-impeded Running Time (Mins)  1.916667     662.608696
# 4            1.71  Un-impeded Running Time (Mins)  2.233333     765.671642
#
#     line_id  mode
# 0  bakerloo  tube
# 1  bakerloo  tube
# 2  bakerloo  tube
# 3  bakerloo  tube
# 4  bakerloo  tube

# %%
px.box(
    df_trains,
    x="line_id",
    y="Speed [m/min]",
    color="Period"
)
# Out:
# <div>
#
#
#             <div id="5d62ee5c-010b-477a-9d66-c094e4101921" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5d62ee5c-010b-477a-9d66-c094e4101921")) {
#                     Plotly.newPlot(
#                         '5d62ee5c-010b-477a-9d66-c094e4101921',
#                         [{"alignmentgroup": "True", "hovertemplate": "Period=Un-impeded Running Time (Mins)<br>line_id=%{x}<br>Speed [m/min]=%{y}<extra></extra>", "legendgroup": "Un-impeded Running Time (Mins)", "marker": {"color": "#636efa"}, "name": "Un-impeded Running Time (Mins)", "notched": false, "offsetgroup": "Un-impeded Running Time (Mins)", "orientation": "v", "showlegend": true, "type": "box", "x": ["bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "bakerloo", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "central", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "victoria", "waterloo-city", "waterloo-city", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "jubilee", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "northern", "north ...

# %%
df_trains = df_trains[df_trains["Period"]=="Un-impeded Running Time (Mins)"].groupby(by=["line_id","mode"]) \
    .agg({"Speed [m/min]":"median"}) \
    .reset_index()
display(df_trains)
# Out:
#               line_id        mode  Speed [m/min]
# 0            bakerloo        tube     526.666667
# 1             central        tube     767.709438
# 2              circle        tube     491.883117
# 3            district        tube     539.318182
# 4                 dlr         dlr    1066.666667
# 5    hammersmith-city        tube     485.895118
# 6             jubilee        tube     720.862968
# 7   london-overground  overground     472.058824
# 8        metropolitan        tube     664.030189
# 9            northern        tube     551.363636
# 10         piccadilly        tube     625.531915
# 11           victoria        tube     652.670455
# 12      waterloo-city        tube     525.636008

# %%
df_buses = pd.read_excel(
    "route-all-bus-speeds-to-p02-2020.xlsx",
    sheet_name="2020-21",
    skiprows=25,
    usecols="C,E",
    header=None
)
df_buses.columns = ["line_id","Speed [miles/hr]"]
df_buses["Speed [m/min]"] = df_buses["Speed [miles/hr]"] * 1609.34 / 60
df_buses.drop(inplace=True, columns="Speed [miles/hr]")
df_buses["mode"] = "bus"
df_buses.head()
# Out:
#   line_id  Speed [m/min] mode
# 0       1     278.392031  bus
# 1       2     257.608086  bus
# 2      2U     262.900364  bus
# 3       3     292.196589  bus
# 4       4     246.081304  bus

# %%
display(df_buses[df_buses["Speed [m/min]"].isna()])
df_buses.dropna(inplace=True)
# Out:
#     line_id  Speed [m/min] mode
# 447     601            NaN  bus
# 448     602            NaN  bus
# 453     625            NaN  bus
# 457     639            NaN  bus
# 460     649            NaN  bus
# 463     669            NaN  bus
# 464     670            NaN  bus
# 527     NG2            NaN  bus
# 558     UL7            NaN  bus

# %%
px.histogram(
    df_buses,
    x="Speed [m/min]"
)
# Out:
# <div>
#
#
#             <div id="e9994101-7e31-42c1-818e-b8fbe61a99dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e9994101-7e31-42c1-818e-b8fbe61a99dc")) {
#                     Plotly.newPlot(
#                         'e9994101-7e31-42c1-818e-b8fbe61a99dc',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Speed [m/min]=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [278.3920313051558, 257.60808629988935, 262.900363974544, 292.1965886589908, 246.08130430290532, 312.2570694309798, 300.01926948937955, 277.6714679729616, 272.3275535371087, 244.2324804812953, 230.8998421591766, 236.4002181163549, 290.35535072544354, 230.38208532347238, 257.1201099216675, 265.9977345722928, 250.25660227703767, 264.4160481498242, 273.44638036352364, 378.07178898881506, 251.5115082645839, 263.3588642004734, 275.4448488728576, 243.9441255881099, 237.94118506822025, 248.78958531086806, 274.1637942669135, 241.71715784185275, 233.26454526659683, 231.49962480796492, 267.00492670477644, 277.17349361167624, 372.6881144476296, 364.4594495613072, 228.4257724435671, 252.623716617914, 277.1994373779309, 215.66714299287025, 311.27611789406814, 244.13557234970511, 275.7958535492981, 253.10732758899772, 235.5382918309748, 257.3615865163818, 247.8809609623513, 237.725134648962, 271.99238066502085, 285.8867